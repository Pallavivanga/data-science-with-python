# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df=pd.read_csv('D:/data science with python/apple_sample.csv')

# %%
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0     7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 1     6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2     5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 3     3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 4    30-Jun-17  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246  15-Jul-16   98.92   99.30   98.50   98.78  30136990
# 247  14-Jul-16   97.39   98.99   97.32   98.79  38918997
# 248  13-Jul-16   97.41   97.67   96.84   96.87  25892171
# 249  12-Jul-16   97.17   97.70   97.12   97.42  24167463
# 250  11-Jul-16   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0   7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 1   6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2   5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 3   3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 4  30-Jun-17  144.45  144.96  143.78  144.02  23024107

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 247 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 248 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 249 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 250 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
type(df['Date'])
# Out:
# pandas.core.series.Series

# %%
df1=pd.read_csv('D:/data science with python/apple_sample.csv',parse_dates=['Date'],index_col='Date')

# %%
df1
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
type('Date')
# Out:
# str

# %%
type(df1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df1.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
df1['2017-1']
# Out:
# C:\Users\PallaviVanga\AppData\Local\Temp\ipykernel_19200\4284124573.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df1['2017-1']
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# ...

# %%
df1['2017-1'].Close.max()
# Out:
# C:\Users\PallaviVanga\AppData\Local\Temp\ipykernel_19200\3424509100.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df1['2017-1'].Close.max()
# 121.95

# %%
df1['2017-1'].Close.mean()
# Out:
# C:\Users\PallaviVanga\AppData\Local\Temp\ipykernel_19200\3493157009.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df1['2017-1'].Close.mean()
# 119.57000000000001

# %%
df1['2017-1-3':'2017-1-25']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# 2017-01-13  119.11  119.62  118.81  119.04  26111948
# 2017-01-12  118.90  119.30  118.21  119.25  27086220
# 2017-01-11  118.74  119.93  118.60  119.75  27588593
# 2017-01-10  118.77  119.38  118.30  119.11  24462051
# 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %%
df1.Close.resample('M').mean()#monthly average of close price
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
df1.Close.resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1.Close.resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2=pd.read_csv('D:/data science with python/aapl_no_dates.csv')

# %%
df2
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
rng=pd.date_range(start='6/1/2017',end='6/30/2017',freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df2.set_index(rng,inplace=True)

# %%
df2
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
df2.Close.plot()
# Out:
# <AxesSubplot:>

# %%
df2.asfreq('W',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-18  143.78  144.50  142.20  142.27  50361093
# 2017-06-25  145.13  147.16  145.11  146.28  35439389

# %%
df2.asfreq('D',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
rng1=pd.date_range(start='1/7/2017',periods=70,freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
import numpy as np

# %%
ts=pd.Series(np.random.randint(1,10,len(rng1)),index=rng1)

# %%
ts.head()
# Out:
# 2017-01-09    9
# 2017-01-10    7
# 2017-01-11    4
# 2017-01-12    1
# 2017-01-13    5
# Freq: B, dtype: int32

# %%
dates=['2017-01-05 2:30:00','Jan 5, 2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105']

# %%
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05 02:30:00', '2017-01-05 14:30:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('5/2/2017',dayfirst=True)
# Out:
# Timestamp('2017-02-05 00:00:00')

# %%
pd.to_datetime('5$2$2017',format='%d$%M$%Y')
# Out:
# Timestamp('2017-01-05 00:02:00')

# %%
dates=['2017-01-05 2:30:00','Jan 5, 2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105','abc']

# %%
pd.to_datetime(dates,errors='ignore')
# Out:
# Index(['2017-01-05 2:30:00', 'Jan 5, 2017 14:30:00', '01/05/2017',
#        '2017.01.05', '2017/01/05', '20170105', 'abc'],
#       dtype='object')

# %%
dates=['2017-01-05 2:30:00','Jan 5, 2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105','abc']

# %%
pd.to_datetime(dates,errors='coerce')
# Out:
# DatetimeIndex(['2017-01-05 02:30:00', '2017-01-05 14:30:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                                'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %%
t=1501356749
pd.to_datetime(t,unit='s')
# Out:
# Timestamp('2017-07-29 19:32:29')

# %%
t1=1664345157
dt=pd.to_datetime([t1],unit='s')
dt
# Out:
# DatetimeIndex(['2022-09-28 06:05:57'], dtype='datetime64[ns]', freq=None)

# %%
#if you want to come back from unix time to epoch 
dt.view('int64')
# Out:
# array([1664345157000000000], dtype=int64)

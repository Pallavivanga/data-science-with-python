# %%
import pandas as pd

# %%
df=pd.read_csv('D:/data science with python/weather2.csv')

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index='date',columns='city',values='humidity')
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       26      80        56
# 5/2/2017       30      83        58
# 5/3/2017       35      85        60

# %%
df.pivot(index='humidity',columns='city')
# Out:
#               date                     temperature
# city       beijing    mumbai  new york     beijing mumbai new york
# humidity
# 26        5/1/2017       NaN       NaN        80.0    NaN      NaN
# 30        5/2/2017       NaN       NaN        77.0    NaN      NaN
# 35        5/3/2017       NaN       NaN        79.0    NaN      NaN
# 56             NaN       NaN  5/1/2017         NaN    NaN     65.0
# 58             NaN       NaN  5/2/2017         NaN    NaN     66.0
# 60             NaN       NaN  5/3/2017         NaN    NaN     68.0
# 80             NaN  5/1/2017       NaN         NaN   75.0      NaN
# 83             NaN  5/2/2017       NaN         NaN   78.0      NaN
# 85             NaN  5/3/2017       NaN         NaN   82.0      NaN

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df=pd.read_csv('D:/data science with python/weather3.csv')

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index='city',columns='date')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df.pivot_table(index='city',columns='date',aggfunc='sum')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index='city',columns='date',aggfunc='count')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai          2        2           2        2
# new york        2        2           2        2

# %%
df.pivot_table(index='city',columns='date',aggfunc='mean')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df.pivot_table(index='city',columns='date',margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
df=pd.read_csv('D:/data science with python/weather4.csv')

# %%
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:8038, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8021 @Substitution("")
#    8022 @Appender(_shared_docs["pivot_table"])
#    8023 def pivot_table(
#    (...)
#    8034     sort=True,
#    8035 ) -> DataFrame:
#    8036     from pandas.core.reshape.pivot import pivot_table
# -> 8038     return pivot_table(
#    8039         self,
#    8040         values=values,
#    8041         index=index,
#    8042         columns=columns,
#    8043         aggfunc=aggfunc,
#    8044         fill_value=fill_value,
#    8045         margins=margins,
# ...

# %%
df
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %%
df=df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city')

# %%
df
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-12-31  53.833333        46.5

# %%
df=pd.read_csv('D:/data science with python/weather5.csv')

# %%
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df=pd.melt(df,id_vars='day')

# %%
df
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
df1=pd.melt(df,id_vars=['day'])
df1[df1['variable']=='chicago']
# Out:
#          day variable  value
# 0     Monday  chicago     32
# 1    Tuesday  chicago     30
# 2  Wednesday  chicago     28
# 3   Thursday  chicago     22
# 4     Friday  chicago     30
# 5   Saturday  chicago     20
# 6     Sunday  chicago     25

# %%
df2=pd.melt(df,id_vars=['day'])
df2[df2['variable']=='chicago']
# Out:
#          day variable  value
# 0     Monday  chicago     32
# 1    Tuesday  chicago     30
# 2  Wednesday  chicago     28
# 3   Thursday  chicago     22
# 4     Friday  chicago     30
# 5   Saturday  chicago     20
# 6     Sunday  chicago     25

# %%
pd.melt(df,id_vars=['day'],var_name='city',value_name='temperature')
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %%
pd.melt(df,id_vars=['day'],val_name='temperature')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 pd.melt(df,id_vars=['day'],val_name='temperature')
#
# TypeError: melt() got an unexpected keyword argument 'val_name'
